# %%
from tensorflow.keras.layers import Input
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model
import numpy as np
import argparse
from tensorflow.keras.layers import Activation, Dense, Input
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import concatenate
from tensorflow.keras.models import Model

import numpy as np
import math
import matplotlib.pyplot as plt
import os

# %%
def build_generator(inputs,
              image_size,
              activation='sigmoid',
              labels=None,
              codes=None):
    """Build a Generator Model
    Stack of BN-ReLU-Conv2DTranpose to generate fake images.
    Output activation is sigmoid instead of tanh in [1].
    Sigmoid converges easily.
    Arguments:
        inputs (Layer): Input layer of the generator (the z-vector)
        image_size (int): Target size of one side 
            (assuming square image)
        activation (string): Name of output activation layer
        labels (tensor): Input labels
        codes (list): 2-dim disentangled codes for InfoGAN
    Returns:
        Model: Generator Model
    """
    image_resize = image_size // 4
    # network parameters
    kernel_size = 5
    layer_filters = [128, 64, 32, 1]

    if labels is not None:
        if codes is None:
            # ACGAN labels
            # concatenate z noise vector and one-hot labels
            inputs = [inputs, labels]
        else:
            # infoGAN codes
            # concatenate z noise vector, 
            # one-hot labels and codes 1 & 2
            inputs = [inputs, labels] + codes
        x = concatenate(inputs, axis=1)
    elif codes is not None:
        # generator 0 of StackedGAN
        inputs = [inputs, codes]
        x = concatenate(inputs, axis=1)
    else:
        # default input is just 100-dim noise (z-code)
        x = inputs

    x = Dense(image_resize * image_resize * layer_filters[0])(x)
    x = Reshape((image_resize, image_resize, layer_filters[0]))(x)

    for filters in layer_filters:
        # first two convolution layers use strides = 2
        # the last two use strides = 1
        if filters > layer_filters[-2]:
            strides = 2
        else:
            strides = 1
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2DTranspose(filters=filters,
                            kernel_size=kernel_size,
                            strides=strides,
                            padding='same')(x)

    if activation is not None:
        x = Activation(activation)(x)

    # generator output is the synthesized image x
    return Model(inputs, x, name='generator')

# %%
def build_discriminator(inputs,
                  activation='sigmoid',
                  num_labels=None,
                  num_codes=None):
    """Build a Discriminator Model
    Stack of LeakyReLU-Conv2D to discriminate real from fake
    The network does not converge with BN so it is not used here
    unlike in [1]
    Arguments:
        inputs (Layer): Input layer of the discriminator (the image)
        activation (string): Name of output activation layer
        num_labels (int): Dimension of one-hot labels for ACGAN & InfoGAN
        num_codes (int): num_codes-dim Q network as output 
                    if StackedGAN or 2 Q networks if InfoGAN
                    
    Returns:
        Model: Discriminator Model
    """
    kernel_size = 5
    layer_filters = [32, 64, 128, 256]

    x = inputs
    for filters in layer_filters:
        # first 3 convolution layers use strides = 2
        # last one uses strides = 1
        if filters == layer_filters[-1]:
            strides = 1
        else:
            strides = 2
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv2D(filters=filters,
                   kernel_size=kernel_size,
                   strides=strides,
                   padding='same')(x)

    x = Flatten()(x)
    # default output is probability that the image is real
    outputs = Dense(1)(x)
    if activation is not None:
        print(activation)
        outputs = Activation(activation)(outputs)

    if num_labels:
        # ACGAN and InfoGAN have 2nd output
        # 2nd output is 10-dim one-hot vector of label
        layer = Dense(layer_filters[-2])(x)
        labels = Dense(num_labels)(layer)
        labels = Activation('softmax', name='label')(labels)
        if num_codes is None:
            outputs = [outputs, labels]
        else:
            # InfoGAN have 3rd and 4th outputs
            # 3rd output is 1-dim continous Q of 1st c given x
            code1 = Dense(1)(layer)
            code1 = Activation('sigmoid', name='code1')(code1)

            # 4th output is 1-dim continuous Q of 2nd c given x
            code2 = Dense(1)(layer)
            code2 = Activation('sigmoid', name='code2')(code2)

            outputs = [outputs, labels, code1, code2]
    elif num_codes is not None:
        # StackedGAN Q0 output
        # z0_recon is reconstruction of z0 normal distribution
        z0_recon =  Dense(num_codes)(x)
        z0_recon = Activation('tanh', name='z0')(z0_recon)
        outputs = [outputs, z0_recon]

    return Model(inputs, outputs, name='discriminator')

# %%
def train(models, x_train, params):
    """Train the Discriminator and Adversarial Networks
    Alternately train Discriminator and Adversarial
    networks by batch.
    Discriminator is trained first with properly labelled
    real and fake images for n_critic times.
    Discriminator weights are clipped as a requirement 
    of Lipschitz constraint.
    Generator is trained next (via Adversarial) with 
    fake images pretending to be real.
    Generate sample images per save_interval
    Arguments:
        models (list): Generator, Discriminator,
            Adversarial models
        x_train (tensor): Train images
        params (list) : Networks parameters
    """
    # the GAN models
    generator, discriminator, adversarial = models
    # network parameters
    (batch_size, latent_size, n_critic, 
            clip_value, train_steps, model_name) = params
    # the generator image is saved every 500 steps
    save_interval = 500
    # noise vector to see how the 
    # generator output evolves during training
    noise_input = np.random.uniform(-1.0,
                                    1.0, 
                                    size=[16, latent_size])
    # number of elements in train dataset
    train_size = x_train.shape[0]
    # labels for real data
    real_labels = np.ones((batch_size, 1))
    for i in range(train_steps):
        # train discriminator n_critic times
        loss = 0
        acc = 0
        for _ in range(n_critic):
            # train the discriminator for 1 batch
            # 1 batch of real (label=1.0) and 
            # fake images (label=-1.0)
            # randomly pick real images from dataset
            rand_indexes = np.random.randint(0,
                                             train_size, 
                                             size=batch_size)
            real_images = x_train[rand_indexes]
            # generate fake images from noise using generator
            # generate noise using uniform distribution
            noise = np.random.uniform(-1.0,
                                      1.0,
                                      size=[batch_size, latent_size])
            fake_images = generator.predict(noise)

            # train the discriminator network
            # real data label=1, fake data label=-1
            # instead of 1 combined batch of real and fake images,
            # train with 1 batch of real data first, then 1 batch
            # of fake images.
            # this tweak prevents the gradient 
            # from vanishing due to opposite
            # signs of real and fake data labels (i.e. +1 and -1) and 
            # small magnitude of weights due to clipping.
            real_loss, real_acc = \
                discriminator.train_on_batch(real_images,
                                             real_labels)
            fake_loss, fake_acc = \
                discriminator.train_on_batch(fake_images,
                                             -real_labels)
            # accumulate average loss and accuracy
            loss += 0.5 * (real_loss + fake_loss)
            acc += 0.5 * (real_acc + fake_acc)

            # clip discriminator weights to satisfy Lipschitz constraint
            for layer in discriminator.layers:
                weights = layer.get_weights()
                weights = [np.clip(weight,
                                   -clip_value,
                                   clip_value) for weight in weights]
                layer.set_weights(weights)

        # average loss and accuracy per n_critic training iterations
        loss /= n_critic
        acc /= n_critic
        log = "%d: [discriminator loss: %f, acc: %f]" % (i, loss, acc)

        # train the adversarial network for 1 batch
        # 1 batch of fake images with label=1.0
        # since the discriminator weights are frozen in 
        # adversarial network only the generator is trained
        # generate noise using uniform distribution
        noise = np.random.uniform(-1.0,
                                  1.0,
                                  size=[batch_size, latent_size])
        # train the adversarial network
        # note that unlike in discriminator training,
        # we do not save the fake images in a variable
        # the fake images go to the discriminator 
        # input of the adversarial for classification
        # fake images are labelled as real
        # log the loss and accuracy
        loss, acc = adversarial.train_on_batch(noise, real_labels)
        log = "%s [adversarial loss: %f, acc: %f]" % (log, loss, acc)
        print(log)
        if (i + 1) % save_interval == 0:
            # plot generator images on a periodic basis
            plot_images(generator,
                        noise_input=noise_input,
                        show=False,
                        step=(i + 1),
                        model_name=model_name)

    # save the model after training the generator
    # the trained generator can be reloaded 
    # for future MNIST digit generation
    generator.save(model_name + ".h5")

# %%
def plot_images(generator,
                noise_input,
                noise_label=None,
                noise_codes=None,
                show=False,
                step=0,
                model_name="gan"):
    """Generate fake images and plot them
    For visualization purposes, generate fake images
    then plot them in a square grid
    # Arguments
        generator (Model): The Generator Model for 
            fake images generation
        noise_input (ndarray): Array of z-vectors
        show (bool): Whether to show plot or not
        step (int): Appended to filename of the save images
        model_name (string): Model name
    """
    os.makedirs(model_name, exist_ok=True)
    filename = os.path.join(model_name, "%05d.png" % step)
    rows = int(math.sqrt(noise_input.shape[0]))
    if noise_label is not None:
        noise_input = [noise_input, noise_label]
        if noise_codes is not None:
            noise_input += noise_codes

    images = generator.predict(noise_input)
    plt.figure(figsize=(2.2, 2.2))
    num_images = images.shape[0]
    image_size = images.shape[1]
    for i in range(num_images):
        plt.subplot(rows, rows, i + 1)
        image = np.reshape(images[i], [image_size, image_size])
        plt.imshow(image, cmap='gray')
        plt.axis('off')
    plt.savefig(filename)
    if show:
        plt.show()
    else:
        plt.close('all')

# %%
def wasserstein_loss(y_label, y_pred):
    return -K.mean(y_label * y_pred)

# %%
def build_and_train_models():
    """Load the dataset, build WGAN discriminator,
    generator, and adversarial models.
    Call the WGAN train routine.
    """
    # load MNIST dataset
    (x_train, _), (_, _) = mnist.load_data()

    # reshape data for CNN as (28, 28, 1) and normalize
    image_size = x_train.shape[1]
    x_train = np.reshape(x_train, [-1, image_size, image_size, 1])
    x_train = x_train.astype('float32') / 255

    model_name = "wgan_mnist"
    # network parameters
    # the latent or z vector is 100-dim
    latent_size = 100
    # hyper parameters from WGAN paper [2]
    n_critic = 5
    clip_value = 0.01
    batch_size = 64
    lr = 5e-5
    train_steps = 40000
    input_shape = (image_size, image_size, 1)

    # build discriminator model
    inputs = Input(shape=input_shape, name='discriminator_input')
    # WGAN uses linear activation in paper [2]
    discriminator = build_discriminator(inputs, activation='linear')
    optimizer = RMSprop(lr=lr)
    # WGAN discriminator uses wassertein loss
    discriminator.compile(loss=wasserstein_loss,
                          optimizer=optimizer,
                          metrics=['accuracy'])
    discriminator.summary()

    # build generator model
    input_shape = (latent_size, )
    inputs = Input(shape=input_shape, name='z_input')
    generator = build_generator(inputs, image_size)
    generator.summary()

    # build adversarial model = generator + discriminator
    # freeze the weights of discriminator during adversarial training
    discriminator.trainable = False
    adversarial = Model(inputs,
                        discriminator(generator(inputs)),
                        name=model_name)
    adversarial.compile(loss=wasserstein_loss,
                        optimizer=optimizer,
                        metrics=['accuracy'])
    adversarial.summary()

    # train discriminator and adversarial networks
    models = (generator, discriminator, adversarial)
    params = (batch_size,
              latent_size,
              n_critic,
              clip_value,
              train_steps,
              model_name)
    train(models, x_train, params)

# %%
def test_generator(generator):
    noise_input = np.random.uniform(-1.0, 1.0, size=[16, 100])
    plot_images(generator,
                noise_input=noise_input,
                show=True,
                model_name="test_outputs")

# %%
build_and_train_models()
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 14796: [discriminator loss: -0.006074, acc: 0.017188] [adversarial loss: -0.093814, acc: 0.000000]
# 14797: [discriminator loss: -0.013214, acc: 0.015625] [adversarial loss: -0.083902, acc: 0.046875]
# 14798: [discriminator loss: -0.013958, acc: 0.021875] [adversarial loss: -0.113639, acc: 0.015625]
# 14799: [discriminator loss: -0.010951, acc: 0.037500] [adversarial loss: -0.121202, acc: 0.093750]
# 14800: [discriminator loss: 0.002957, acc: 0.025000] [adversarial loss: -0.112484, acc: 0.046875]
# 14801: [discriminator loss: -0.013993, acc: 0.026562] [adversarial loss: -0.133076, acc: 0.109375]
# 14802: [discriminator loss: 0.006344, acc: 0.032813] [adversarial loss: -0.039405, acc: 0.015625]
# 14803: [discriminator loss: -0.018442, acc: 0.007812] [adversarial loss: -0.117390, acc: 0.015625]
# 14804: [discriminator loss: -0.015276, acc: 0.006250] [adversarial loss: -0.071692, acc: 0.000000]
# 14805: [discriminator loss: -0.009076, acc: 0.009375] [adversarial loss: -0.023089, acc: 0.000000]
# 14806: [discriminator loss: -0.016618, acc: 0.012500] [adversarial loss: -0.068427, acc: 0.046875]
# 14807: [discriminator loss: -0.011751, acc: 0.012500] [adversarial loss: -0.047760, acc: 0.000000]
# 14808: [discriminator loss: -0.001712, acc: 0.009375] [adversarial loss: -0.042428, acc: 0.000000]
# 14809: [discriminator loss: -0.016434, acc: 0.009375] [adversarial loss: -0.036123, acc: 0.015625]
# 14810: [discriminator loss: 0.008400, acc: 0.006250] [adversarial loss: -0.073733, acc: 0.015625]
# 14811: [discriminator loss: -0.007757, acc: 0.001563] [adversarial loss: -0.040904, acc: 0.000000]
# 14812: [discriminator loss: -0.003019, acc: 0.000000] [adversarial loss: -0.066399, acc: 0.000000]
# 14813: [discriminator loss: -0.024701, acc: 0.001563] [adversarial loss: -0.087104, acc: 0.000000]
# 14814: [discriminator loss: -0.015087, acc: 0.003125] [adversarial loss: -0.059386, acc: 0.000000]
# 14815: [discriminator loss: -0.018751, acc: 0.009375] [adversarial loss: -0.055418, acc: 0.015625]
# 14816: [discriminator loss: -0.007348, acc: 0.000000] [adversarial loss: -0.078947, acc: 0.015625]
# 14817: [discriminator loss: -0.013306, acc: 0.006250] [adversarial loss: -0.056807, acc: 0.015625]
# 14818: [discriminator loss: -0.017654, acc: 0.001563] [adversarial loss: -0.036510, acc: 0.000000]
# 14819: [discriminator loss: -0.016041, acc: 0.007812] [adversarial loss: -0.090510, acc: 0.031250]
# 14820: [discriminator loss: -0.009495, acc: 0.009375] [adversarial loss: -0.089379, acc: 0.046875]
# 14821: [discriminator loss: 0.000756, acc: 0.004687] [adversarial loss: -0.067254, acc: 0.000000]
# 14822: [discriminator loss: -0.002700, acc: 0.003125] [adversarial loss: -0.036060, acc: 0.015625]
# 14823: [discriminator loss: -0.006848, acc: 0.010937] [adversarial loss: -0.038920, acc: 0.000000]
# 14824: [discriminator loss: -0.007638, acc: 0.007812] [adversarial loss: -0.029084, acc: 0.000000]
# 14825: [discriminator loss: -0.014843, acc: 0.017188] [adversarial loss: -0.073773, acc: 0.046875]
# 14826: [discriminator loss: -0.019699, acc: 0.039062] [adversarial loss: -0.128009, acc: 0.078125]
# 14827: [discriminator loss: -0.010636, acc: 0.026562] [adversarial loss: -0.086574, acc: 0.046875]
# 14828: [discriminator loss: -0.002510, acc: 0.007812] [adversarial loss: -0.079588, acc: 0.000000]
# 14829: [discriminator loss: -0.013535, acc: 0.001563] [adversarial loss: -0.043153, acc: 0.015625]
# 14830: [discriminator loss: -0.010040, acc: 0.004687] [adversarial loss: -0.034077, acc: 0.015625]
# 14831: [discriminator loss: -0.009733, acc: 0.017188] [adversarial loss: -0.016108, acc: 0.015625]
# 14832: [discriminator loss: -0.021760, acc: 0.028125] [adversarial loss: -0.119792, acc: 0.078125]
# 14833: [discriminator loss: -0.049006, acc: 0.035937] [adversarial loss: -0.145944, acc: 0.187500]
# 14834: [discriminator loss: 0.003706, acc: 0.051562] [adversarial loss: -0.071596, acc: 0.062500]
# 14835: [discriminator loss: 0.004926, acc: 0.031250] [adversarial loss: -0.083321, acc: 0.031250]
# 14836: [discriminator loss: 0.002649, acc: 0.010937] [adversarial loss: -0.101380, acc: 0.000000]
# 14837: [discriminator loss: -0.009125, acc: 0.007812] [adversarial loss: -0.067746, acc: 0.031250]
# 14838: [discriminator loss: -0.006083, acc: 0.006250] [adversarial loss: -0.085370, acc: 0.015625]
# 14839: [discriminator loss: -0.011368, acc: 0.004687] [adversarial loss: -0.091238, acc: 0.000000]
# 14840: [discriminator loss: -0.009562, acc: 0.006250] [adversarial loss: -0.080978, acc: 0.000000]
# 14841: [discriminator loss: -0.020193, acc: 0.023438] [adversarial loss: -0.017047, acc: 0.000000]
# 14842: [discriminator loss: -0.028891, acc: 0.015625] [adversarial loss: -0.039112, acc: 0.015625]
# 14843: [discriminator loss: -0.011673, acc: 0.031250] [adversarial loss: -0.061492, acc: 0.078125]
# 14844: [discriminator loss: -0.012556, acc: 0.056250] [adversarial loss: -0.048419, acc: 0.046875]
# 14845: [discriminator loss: -0.008864, acc: 0.032813] [adversarial loss: -0.181782, acc: 0.093750]
# 14846: [discriminator loss: -0.000780, acc: 0.025000] [adversarial loss: -0.094599, acc: 0.062500]
# 14847: [discriminator loss: 0.003186, acc: 0.021875] [adversarial loss: -0.073739, acc: 0.062500]
# 14848: [discriminator loss: 0.000718, acc: 0.007812] [adversarial loss: -0.028344, acc: 0.000000]
# 14849: [discriminator loss: -0.015755, acc: 0.000000] [adversarial loss: -0.047286, acc: 0.015625]
# 14850: [discriminator loss: -0.015225, acc: 0.004687] [adversarial loss: -0.015804, acc: 0.000000]
# 14851: [discriminator loss: -0.007566, acc: 0.000000] [adversarial loss: -0.030948, acc: 0.000000]
# 14852: [discriminator loss: -0.014391, acc: 0.000000] [adversarial loss: -0.027068, acc: 0.000000]
# 14853: [discriminator loss: -0.018589, acc: 0.001563] [adversarial loss: -0.021844, acc: 0.000000]
# 14854: [discriminator loss: 0.008341, acc: 0.000000] [adversarial loss: -0.048144, acc: 0.000000]
# 14855: [discriminator loss: -0.007898, acc: 0.003125] [adversarial loss: -0.043513, acc: 0.000000]
# 14856: [discriminator loss: -0.005642, acc: 0.004687] [adversarial loss: -0.061583, acc: 0.000000]
# 14857: [discriminator loss: -0.018063, acc: 0.003125] [adversarial loss: -0.055149, acc: 0.031250]
# 14858: [discriminator loss: 0.004379, acc: 0.010937] [adversarial loss: -0.080874, acc: 0.000000]
# 14859: [discriminator loss: -0.017810, acc: 0.003125] [adversarial loss: -0.059212, acc: 0.000000]
# 14860: [discriminator loss: -0.010610, acc: 0.009375] [adversarial loss: -0.093386, acc: 0.000000]
# 14861: [discriminator loss: -0.010761, acc: 0.006250] [adversarial loss: -0.053959, acc: 0.000000]
# 14862: [discriminator loss: -0.007760, acc: 0.004687] [adversarial loss: -0.079339, acc: 0.000000]
# 14863: [discriminator loss: -0.009623, acc: 0.003125] [adversarial loss: -0.091190, acc: 0.000000]
# 14864: [discriminator loss: -0.015264, acc: 0.001563] [adversarial loss: -0.065998, acc: 0.000000]
# 14865: [discriminator loss: -0.006953, acc: 0.000000] [adversarial loss: -0.115972, acc: 0.015625]
# 14866: [discriminator loss: -0.010584, acc: 0.001563] [adversarial loss: -0.075532, acc: 0.000000]
# 14867: [discriminator loss: -0.009015, acc: 0.012500] [adversarial loss: -0.092130, acc: 0.015625]
# 14868: [discriminator loss: -0.008674, acc: 0.004687] [adversarial loss: -0.075536, acc: 0.015625]
# 14869: [discriminator loss: -0.015427, acc: 0.003125] [adversarial loss: -0.057559, acc: 0.031250]
# 14870: [discriminator loss: -0.007957, acc: 0.021875] [adversarial loss: -0.048743, acc: 0.031250]
# 14871: [discriminator loss: -0.016579, acc: 0.009375] [adversarial loss: -0.083405, acc: 0.015625]
# 14872: [discriminator loss: -0.034636, acc: 0.017188] [adversarial loss: -0.041113, acc: 0.000000]
# 14873: [discriminator loss: -0.003983, acc: 0.028125] [adversarial loss: -0.073966, acc: 0.031250]
# 14874: [discriminator loss: -0.004965, acc: 0.010937] [adversarial loss: -0.060328, acc: 0.000000]
# 14875: [discriminator loss: -0.016224, acc: 0.006250] [adversarial loss: -0.059341, acc: 0.015625]
# 14876: [discriminator loss: -0.014460, acc: 0.007812] [adversarial loss: -0.038531, acc: 0.000000]
# 14877: [discriminator loss: -0.005693, acc: 0.006250] [adversarial loss: -0.042070, acc: 0.046875]
# 14878: [discriminator loss: -0.005651, acc: 0.001563] [adversarial loss: 0.001221, acc: 0.015625]
# 14879: [discriminator loss: -0.026020, acc: 0.012500] [adversarial loss: -0.073216, acc: 0.046875]
# 14880: [discriminator loss: -0.012067, acc: 0.010937] [adversarial loss: -0.058445, acc: 0.031250]
# 14881: [discriminator loss: -0.020771, acc: 0.021875] [adversarial loss: -0.030339, acc: 0.062500]
# 14882: [discriminator loss: -0.024289, acc: 0.035937] [adversarial loss: -0.062066, acc: 0.093750]
# 14883: [discriminator loss: -0.014834, acc: 0.028125] [adversarial loss: -0.017802, acc: 0.078125]
# 14884: [discriminator loss: -0.009951, acc: 0.015625] [adversarial loss: -0.038032, acc: 0.000000]
# 14885: [discriminator loss: -0.009029, acc: 0.001563] [adversarial loss: -0.053080, acc: 0.000000]
# 14886: [discriminator loss: -0.029266, acc: 0.004687] [adversarial loss: -0.014599, acc: 0.015625]
# 14887: [discriminator loss: -0.010245, acc: 0.001563] [adversarial loss: -0.009000, acc: 0.000000]
# 14888: [discriminator loss: -0.014069, acc: 0.007812] [adversarial loss: -0.030977, acc: 0.015625]
# 14889: [discriminator loss: -0.006184, acc: 0.006250] [adversarial loss: -0.084289, acc: 0.015625]
# 14890: [discriminator loss: -0.020000, acc: 0.001563] [adversarial loss: -0.028818, acc: 0.000000]
# 14891: [discriminator loss: -0.015076, acc: 0.015625] [adversarial loss: -0.033353, acc: 0.000000]
# 14892: [discriminator loss: 0.002801, acc: 0.014063] [adversarial loss: -0.084329, acc: 0.015625]
# 14893: [discriminator loss: -0.011223, acc: 0.004687] [adversarial loss: -0.062784, acc: 0.000000]
# 14894: [discriminator loss: -0.006306, acc: 0.004687] [adversarial loss: -0.077287, acc: 0.000000]
# 14895: [discriminator loss: -0.012474, acc: 0.003125] [adversarial loss: -0.075162, acc: 0.000000]
# 14896: [discriminator loss: -0.000059, acc: 0.001563] [adversarial loss: -0.098781, acc: 0.000000]
# 14897: [discriminator loss: -0.013985, acc: 0.000000] [adversarial loss: -0.064142, acc: 0.000000]
# 14898: [discriminator loss: -0.011143, acc: 0.001563] [adversarial loss: -0.054043, acc: 0.000000]
# 14899: [discriminator loss: 0.000186, acc: 0.003125] [adversarial loss: -0.077556, acc: 0.000000]
# 14900: [discriminator loss: -0.007485, acc: 0.000000] [adversarial loss: -0.079005, acc: 0.000000]
# 14901: [discriminator loss: -0.015786, acc: 0.001563] [adversarial loss: -0.068451, acc: 0.000000]
# 14902: [discriminator loss: -0.009636, acc: 0.000000] [adversarial loss: -0.103983, acc: 0.000000]
# 14903: [discriminator loss: -0.005495, acc: 0.004687] [adversarial loss: -0.094323, acc: 0.000000]
# 14904: [discriminator loss: -0.011566, acc: 0.004687] [adversarial loss: -0.081568, acc: 0.046875]
# 14905: [discriminator loss: -0.020458, acc: 0.012500] [adversarial loss: -0.036558, acc: 0.000000]
# 14906: [discriminator loss: -0.019314, acc: 0.021875] [adversarial loss: -0.064104, acc: 0.015625]
# 14907: [discriminator loss: -0.020531, acc: 0.043750] [adversarial loss: -0.081565, acc: 0.031250]
# 14908: [discriminator loss: -0.006659, acc: 0.020313] [adversarial loss: -0.070849, acc: 0.046875]
# 14909: [discriminator loss: 0.006791, acc: 0.015625] [adversarial loss: -0.094622, acc: 0.015625]
# 14910: [discriminator loss: -0.017282, acc: 0.009375] [adversarial loss: -0.124673, acc: 0.015625]
# 14911: [discriminator loss: -0.006534, acc: 0.010937] [adversarial loss: -0.091280, acc: 0.000000]
# 14912: [discriminator loss: -0.016144, acc: 0.007812] [adversarial loss: -0.119113, acc: 0.000000]
# 14913: [discriminator loss: 0.000348, acc: 0.004687] [adversarial loss: -0.068117, acc: 0.000000]
# 14914: [discriminator loss: -0.004750, acc: 0.018750] [adversarial loss: -0.044862, acc: 0.031250]
# 14915: [discriminator loss: -0.005771, acc: 0.020313] [adversarial loss: -0.083993, acc: 0.000000]
# 14916: [discriminator loss: -0.014890, acc: 0.012500] [adversarial loss: -0.095862, acc: 0.015625]
# 14917: [discriminator loss: -0.011632, acc: 0.004687] [adversarial loss: -0.028852, acc: 0.000000]
# 14918: [discriminator loss: -0.025535, acc: 0.010937] [adversarial loss: -0.066664, acc: 0.031250]
# 14919: [discriminator loss: -0.019350, acc: 0.014063] [adversarial loss: -0.016305, acc: 0.015625]
# 14920: [discriminator loss: -0.016388, acc: 0.017188] [adversarial loss: -0.110667, acc: 0.062500]
# 14921: [discriminator loss: -0.021668, acc: 0.015625] [adversarial loss: -0.054286, acc: 0.062500]
# 14922: [discriminator loss: 0.001430, acc: 0.003125] [adversarial loss: -0.062999, acc: 0.000000]
# 14923: [discriminator loss: -0.017472, acc: 0.001563] [adversarial loss: -0.022219, acc: 0.000000]
# 14924: [discriminator loss: -0.025079, acc: 0.001563] [adversarial loss: -0.001146, acc: 0.000000]
# 14925: [discriminator loss: 0.001294, acc: 0.001563] [adversarial loss: -0.059109, acc: 0.000000]
# 14926: [discriminator loss: -0.017843, acc: 0.001563] [adversarial loss: -0.046398, acc: 0.000000]
# 14927: [discriminator loss: -0.003921, acc: 0.006250] [adversarial loss: -0.066521, acc: 0.000000]
# 14928: [discriminator loss: 0.003441, acc: 0.001563] [adversarial loss: -0.058705, acc: 0.000000]
# 14929: [discriminator loss: -0.000437, acc: 0.000000] [adversarial loss: -0.076728, acc: 0.000000]
# 14930: [discriminator loss: -0.004580, acc: 0.000000] [adversarial loss: -0.059009, acc: 0.000000]
# 14931: [discriminator loss: -0.018073, acc: 0.006250] [adversarial loss: -0.061880, acc: 0.031250]
# 14932: [discriminator loss: -0.008475, acc: 0.018750] [adversarial loss: -0.071544, acc: 0.000000]
# 14933: [discriminator loss: -0.015005, acc: 0.012500] [adversarial loss: -0.067779, acc: 0.015625]
# 14934: [discriminator loss: -0.031555, acc: 0.032813] [adversarial loss: -0.063054, acc: 0.031250]
# 14935: [discriminator loss: -0.005844, acc: 0.025000] [adversarial loss: -0.063978, acc: 0.015625]
# 14936: [discriminator loss: -0.019423, acc: 0.025000] [adversarial loss: -0.036755, acc: 0.000000]
# 14937: [discriminator loss: -0.013479, acc: 0.028125] [adversarial loss: -0.067924, acc: 0.031250]
# 14938: [discriminator loss: -0.019252, acc: 0.023438] [adversarial loss: -0.081529, acc: 0.015625]
# 14939: [discriminator loss: -0.023657, acc: 0.025000] [adversarial loss: -0.108647, acc: 0.015625]
# 14940: [discriminator loss: -0.011466, acc: 0.023438] [adversarial loss: -0.051009, acc: 0.000000]
# 14941: [discriminator loss: -0.000686, acc: 0.017188] [adversarial loss: -0.075452, acc: 0.031250]
# 14942: [discriminator loss: -0.007712, acc: 0.017188] [adversarial loss: -0.070920, acc: 0.000000]
# 14943: [discriminator loss: 0.001077, acc: 0.007812] [adversarial loss: -0.098669, acc: 0.000000]
# 14944: [discriminator loss: -0.014097, acc: 0.018750] [adversarial loss: -0.065961, acc: 0.015625]
# 14945: [discriminator loss: -0.005513, acc: 0.012500] [adversarial loss: -0.090692, acc: 0.000000]
# 14946: [discriminator loss: -0.008941, acc: 0.001563] [adversarial loss: -0.066043, acc: 0.000000]
# 14947: [discriminator loss: -0.003788, acc: 0.003125] [adversarial loss: -0.072077, acc: 0.000000]
# 14948: [discriminator loss: -0.001117, acc: 0.001563] [adversarial loss: -0.079931, acc: 0.000000]
# 14949: [discriminator loss: -0.023648, acc: 0.000000] [adversarial loss: -0.078976, acc: 0.015625]
# 14950: [discriminator loss: -0.008198, acc: 0.006250] [adversarial loss: -0.078718, acc: 0.000000]
# 14951: [discriminator loss: -0.010205, acc: 0.004687] [adversarial loss: -0.063303, acc: 0.000000]
# 14952: [discriminator loss: -0.012646, acc: 0.001563] [adversarial loss: -0.097364, acc: 0.015625]
# 14953: [discriminator loss: -0.012841, acc: 0.001563] [adversarial loss: -0.074076, acc: 0.000000]
# 14954: [discriminator loss: -0.012426, acc: 0.000000] [adversarial loss: -0.093191, acc: 0.000000]
# 14955: [discriminator loss: -0.020782, acc: 0.000000] [adversarial loss: -0.098817, acc: 0.000000]
# 14956: [discriminator loss: -0.018640, acc: 0.007812] [adversarial loss: -0.055204, acc: 0.015625]
# 14957: [discriminator loss: -0.004176, acc: 0.017188] [adversarial loss: -0.092151, acc: 0.015625]
# 14958: [discriminator loss: -0.007411, acc: 0.006250] [adversarial loss: -0.102232, acc: 0.000000]
# 14959: [discriminator loss: -0.007585, acc: 0.010937] [adversarial loss: -0.085663, acc: 0.000000]
# 14960: [discriminator loss: -0.009664, acc: 0.018750] [adversarial loss: -0.076898, acc: 0.015625]
# 14961: [discriminator loss: -0.012558, acc: 0.004687] [adversarial loss: -0.045854, acc: 0.000000]
# 14962: [discriminator loss: -0.008956, acc: 0.001563] [adversarial loss: -0.068373, acc: 0.000000]
# 14963: [discriminator loss: -0.016990, acc: 0.001563] [adversarial loss: -0.019156, acc: 0.000000]
# 14964: [discriminator loss: 0.002254, acc: 0.000000] [adversarial loss: -0.028895, acc: 0.000000]
# 14965: [discriminator loss: -0.006123, acc: 0.000000] [adversarial loss: -0.049163, acc: 0.000000]
# 14966: [discriminator loss: -0.006325, acc: 0.001563] [adversarial loss: -0.060521, acc: 0.000000]
# 14967: [discriminator loss: -0.019555, acc: 0.000000] [adversarial loss: -0.052648, acc: 0.000000]
# 14968: [discriminator loss: -0.021781, acc: 0.001563] [adversarial loss: -0.019755, acc: 0.015625]
# 14969: [discriminator loss: -0.022995, acc: 0.017188] [adversarial loss: 0.000456, acc: 0.015625]
# 14970: [discriminator loss: -0.011241, acc: 0.010937] [adversarial loss: -0.008154, acc: 0.000000]
# 14971: [discriminator loss: 0.003709, acc: 0.010937] [adversarial loss: -0.031180, acc: 0.000000]
# 14972: [discriminator loss: -0.001950, acc: 0.006250] [adversarial loss: -0.052887, acc: 0.000000]
# 14973: [discriminator loss: -0.007922, acc: 0.001563] [adversarial loss: -0.043020, acc: 0.000000]
# 14974: [discriminator loss: -0.012238, acc: 0.000000] [adversarial loss: -0.043782, acc: 0.000000]
# 14975: [discriminator loss: -0.034400, acc: 0.021875] [adversarial loss: -0.035945, acc: 0.031250]
# 14976: [discriminator loss: -0.031236, acc: 0.032813] [adversarial loss: -0.025045, acc: 0.046875]
# 14977: [discriminator loss: -0.007397, acc: 0.046875] [adversarial loss: -0.116180, acc: 0.093750]
# 14978: [discriminator loss: 0.007550, acc: 0.042188] [adversarial loss: -0.020197, acc: 0.000000]
# 14979: [discriminator loss: -0.004582, acc: 0.025000] [adversarial loss: -0.103045, acc: 0.031250]
# 14980: [discriminator loss: 0.002133, acc: 0.012500] [adversarial loss: -0.047869, acc: 0.000000]
# 14981: [discriminator loss: -0.010571, acc: 0.004687] [adversarial loss: -0.087118, acc: 0.000000]
# 14982: [discriminator loss: -0.019884, acc: 0.004687] [adversarial loss: -0.054902, acc: 0.000000]
# 14983: [discriminator loss: -0.007008, acc: 0.004687] [adversarial loss: -0.057184, acc: 0.000000]
# 14984: [discriminator loss: -0.010618, acc: 0.003125] [adversarial loss: -0.038199, acc: 0.000000]
# 14985: [discriminator loss: -0.019430, acc: 0.004687] [adversarial loss: -0.030561, acc: 0.000000]
# 14986: [discriminator loss: -0.004514, acc: 0.003125] [adversarial loss: -0.005403, acc: 0.000000]
# 14987: [discriminator loss: -0.004916, acc: 0.004687] [adversarial loss: -0.046019, acc: 0.000000]
# 14988: [discriminator loss: -0.018269, acc: 0.000000] [adversarial loss: -0.053525, acc: 0.000000]
# 14989: [discriminator loss: -0.017074, acc: 0.004687] [adversarial loss: -0.080283, acc: 0.062500]
# 14990: [discriminator loss: -0.015804, acc: 0.028125] [adversarial loss: -0.060531, acc: 0.062500]
# 14991: [discriminator loss: -0.000846, acc: 0.018750] [adversarial loss: -0.080694, acc: 0.000000]
# 14992: [discriminator loss: -0.002227, acc: 0.004687] [adversarial loss: -0.080175, acc: 0.015625]
# 14993: [discriminator loss: -0.007620, acc: 0.000000] [adversarial loss: -0.058954, acc: 0.000000]
# 14994: [discriminator loss: -0.011794, acc: 0.001563] [adversarial loss: -0.026369, acc: 0.000000]
# 14995: [discriminator loss: -0.013429, acc: 0.001563] [adversarial loss: -0.068700, acc: 0.000000]
# 14996: [discriminator loss: -0.009893, acc: 0.000000] [adversarial loss: -0.076245, acc: 0.000000]
# 14997: [discriminator loss: -0.021195, acc: 0.010937] [adversarial loss: -0.071858, acc: 0.000000]
# 14998: [discriminator loss: -0.004113, acc: 0.004687] [adversarial loss: -0.031851, acc: 0.000000]
# 14999: [discriminator loss: -0.007052, acc: 0.006250] [adversarial loss: -0.070319, acc: 0.000000]
# 15000: [discriminator loss: -0.007777, acc: 0.001563] [adversarial loss: -0.071559, acc: 0.000000]
# 15001: [discriminator loss: -0.011328, acc: 0.000000] [adversarial loss: -0.106931, acc: 0.000000]
# 15002: [discriminator loss: -0.005823, acc: 0.001563] [adversarial loss: -0.092232, acc: 0.000000]
# 15003: [discriminator loss: 0.002533, acc: 0.001563] [adversarial loss: -0.120629, acc: 0.000000]
# 15004: [discriminator loss: -0.010460, acc: 0.000000] [adversarial loss: -0.105938, acc: 0.015625]
# 15005: [discriminator loss: -0.008258, acc: 0.003125] [adversarial loss: -0.091527, acc: 0.046875]
# 15006: [discriminator loss: -0.003753, acc: 0.001563] [adversarial loss: -0.098241, acc: 0.000000]
# 15007: [discriminator loss: -0.008011, acc: 0.000000] [adversarial loss: -0.077279, acc: 0.000000]
# 15008: [discriminator loss: -0.015513, acc: 0.000000] [adversarial loss: -0.067609, acc: 0.000000]
# 15009: [discriminator loss: -0.021201, acc: 0.009375] [adversarial loss: -0.052184, acc: 0.015625]
# 15010: [discriminator loss: -0.003777, acc: 0.014063] [adversarial loss: -0.067358, acc: 0.000000]
# 15011: [discriminator loss: -0.003340, acc: 0.006250] [adversarial loss: -0.037383, acc: 0.000000]
# 15012: [discriminator loss: -0.003542, acc: 0.004687] [adversarial loss: -0.100927, acc: 0.000000]
# 15013: [discriminator loss: -0.032644, acc: 0.006250] [adversarial loss: -0.084558, acc: 0.015625]
# 15014: [discriminator loss: -0.004524, acc: 0.004687] [adversarial loss: -0.028878, acc: 0.000000]
# 15015: [discriminator loss: -0.015395, acc: 0.004687] [adversarial loss: -0.065519, acc: 0.000000]
# 15016: [discriminator loss: -0.017260, acc: 0.000000] [adversarial loss: -0.058850, acc: 0.015625]
# 15017: [discriminator loss: -0.006789, acc: 0.003125] [adversarial loss: -0.052082, acc: 0.015625]
# 15018: [discriminator loss: -0.014246, acc: 0.010937] [adversarial loss: -0.073033, acc: 0.031250]
# 15019: [discriminator loss: -0.009799, acc: 0.014063] [adversarial loss: -0.023439, acc: 0.031250]
# 15020: [discriminator loss: -0.029292, acc: 0.020313] [adversarial loss: -0.010466, acc: 0.031250]
# 15021: [discriminator loss: 0.004898, acc: 0.017188] [adversarial loss: -0.046383, acc: 0.000000]
# 15022: [discriminator loss: -0.015938, acc: 0.012500] [adversarial loss: -0.071299, acc: 0.031250]
# 15023: [discriminator loss: -0.001599, acc: 0.000000] [adversarial loss: -0.039421, acc: 0.000000]
# 15024: [discriminator loss: -0.019746, acc: 0.001563] [adversarial loss: -0.042846, acc: 0.000000]
# 15025: [discriminator loss: -0.013631, acc: 0.001563] [adversarial loss: -0.083512, acc: 0.000000]
# 15026: [discriminator loss: -0.008050, acc: 0.000000] [adversarial loss: -0.049020, acc: 0.000000]
# 15027: [discriminator loss: -0.015831, acc: 0.000000] [adversarial loss: -0.058561, acc: 0.000000]
# 15028: [discriminator loss: -0.010404, acc: 0.003125] [adversarial loss: -0.074098, acc: 0.000000]
# 15029: [discriminator loss: -0.017825, acc: 0.003125] [adversarial loss: -0.050700, acc: 0.000000]
# 15030: [discriminator loss: -0.001072, acc: 0.004687] [adversarial loss: -0.056570, acc: 0.000000]
# 15031: [discriminator loss: -0.018591, acc: 0.006250] [adversarial loss: -0.042724, acc: 0.000000]
# 15032: [discriminator loss: -0.020264, acc: 0.007812] [adversarial loss: -0.042842, acc: 0.000000]
# 15033: [discriminator loss: -0.022618, acc: 0.021875] [adversarial loss: -0.095768, acc: 0.031250]
# 15034: [discriminator loss: -0.014231, acc: 0.020313] [adversarial loss: -0.088479, acc: 0.031250]
# 15035: [discriminator loss: -0.007783, acc: 0.009375] [adversarial loss: -0.116290, acc: 0.000000]
# 15036: [discriminator loss: -0.005499, acc: 0.000000] [adversarial loss: -0.095428, acc: 0.000000]
# 15037: [discriminator loss: -0.002403, acc: 0.007812] [adversarial loss: -0.105188, acc: 0.000000]
# 15038: [discriminator loss: -0.005744, acc: 0.009375] [adversarial loss: -0.079396, acc: 0.000000]
# 15039: [discriminator loss: -0.000946, acc: 0.000000] [adversarial loss: -0.070607, acc: 0.000000]
# 15040: [discriminator loss: -0.003664, acc: 0.003125] [adversarial loss: -0.072153, acc: 0.000000]
# 15041: [discriminator loss: -0.011925, acc: 0.003125] [adversarial loss: -0.102184, acc: 0.000000]
# 15042: [discriminator loss: -0.015439, acc: 0.003125] [adversarial loss: -0.094904, acc: 0.000000]
# 15043: [discriminator loss: -0.002491, acc: 0.010937] [adversarial loss: -0.062315, acc: 0.000000]
# 15044: [discriminator loss: -0.014216, acc: 0.007812] [adversarial loss: -0.065935, acc: 0.046875]
# 15045: [discriminator loss: -0.007464, acc: 0.040625] [adversarial loss: -0.039917, acc: 0.046875]
# 15046: [discriminator loss: -0.019065, acc: 0.050000] [adversarial loss: -0.054896, acc: 0.093750]
# 15047: [discriminator loss: -0.000555, acc: 0.018750] [adversarial loss: -0.116862, acc: 0.062500]
# 15048: [discriminator loss: -0.000660, acc: 0.009375] [adversarial loss: -0.043153, acc: 0.015625]
# 15049: [discriminator loss: -0.005308, acc: 0.001563] [adversarial loss: -0.030195, acc: 0.000000]
# 15050: [discriminator loss: -0.011094, acc: 0.000000] [adversarial loss: -0.035873, acc: 0.000000]
# 15051: [discriminator loss: -0.009977, acc: 0.001563] [adversarial loss: -0.024836, acc: 0.000000]
# 15052: [discriminator loss: -0.009036, acc: 0.000000] [adversarial loss: -0.022528, acc: 0.000000]
# 15053: [discriminator loss: -0.019173, acc: 0.003125] [adversarial loss: 0.009952, acc: 0.000000]
# 15054: [discriminator loss: -0.005311, acc: 0.000000] [adversarial loss: -0.038138, acc: 0.000000]
# 15055: [discriminator loss: -0.003960, acc: 0.000000] [adversarial loss: -0.027977, acc: 0.000000]
# 15056: [discriminator loss: -0.020067, acc: 0.001563] [adversarial loss: -0.014212, acc: 0.000000]
# 15057: [discriminator loss: 0.010797, acc: 0.001563] [adversarial loss: -0.028464, acc: 0.000000]
# 15058: [discriminator loss: -0.008794, acc: 0.000000] [adversarial loss: -0.039765, acc: 0.000000]
# 15059: [discriminator loss: -0.000938, acc: 0.000000] [adversarial loss: -0.046184, acc: 0.000000]
# 15060: [discriminator loss: -0.005241, acc: 0.000000] [adversarial loss: -0.045267, acc: 0.000000]
# 15061: [discriminator loss: -0.004951, acc: 0.000000] [adversarial loss: -0.042620, acc: 0.000000]
# 15062: [discriminator loss: -0.008104, acc: 0.000000] [adversarial loss: -0.069450, acc: 0.000000]
# 15063: [discriminator loss: -0.008430, acc: 0.000000] [adversarial loss: -0.050542, acc: 0.000000]
# 15064: [discriminator loss: -0.010024, acc: 0.000000] [adversarial loss: -0.064504, acc: 0.000000]
# 15065: [discriminator loss: -0.010817, acc: 0.001563] [adversarial loss: -0.039285, acc: 0.000000]
# 15066: [discriminator loss: -0.015518, acc: 0.001563] [adversarial loss: -0.031621, acc: 0.015625]
# 15067: [discriminator loss: -0.020801, acc: 0.026562] [adversarial loss: -0.065761, acc: 0.062500]
# 15068: [discriminator loss: -0.010267, acc: 0.032813] [adversarial loss: -0.039258, acc: 0.031250]
# 15069: [discriminator loss: -0.013083, acc: 0.034375] [adversarial loss: -0.052435, acc: 0.015625]
# 15070: [discriminator loss: -0.020899, acc: 0.004687] [adversarial loss: -0.058456, acc: 0.000000]
# 15071: [discriminator loss: -0.016603, acc: 0.000000] [adversarial loss: -0.077717, acc: 0.000000]
# 15072: [discriminator loss: -0.003393, acc: 0.000000] [adversarial loss: -0.064790, acc: 0.000000]
# 15073: [discriminator loss: -0.002273, acc: 0.000000] [adversarial loss: -0.079804, acc: 0.000000]
# 15074: [discriminator loss: -0.002814, acc: 0.003125] [adversarial loss: -0.094013, acc: 0.000000]
# 15075: [discriminator loss: -0.014283, acc: 0.003125] [adversarial loss: -0.079937, acc: 0.000000]
# 15076: [discriminator loss: -0.009525, acc: 0.006250] [adversarial loss: -0.066824, acc: 0.015625]
# 15077: [discriminator loss: -0.008016, acc: 0.010937] [adversarial loss: -0.051005, acc: 0.000000]
# 15078: [discriminator loss: -0.015941, acc: 0.029687] [adversarial loss: -0.062457, acc: 0.015625]
# 15079: [discriminator loss: -0.013059, acc: 0.035937] [adversarial loss: -0.062644, acc: 0.031250]
# 15080: [discriminator loss: -0.021553, acc: 0.028125] [adversarial loss: -0.057510, acc: 0.046875]
# 15081: [discriminator loss: -0.005935, acc: 0.050000] [adversarial loss: -0.057177, acc: 0.031250]
# 15082: [discriminator loss: -0.000683, acc: 0.007812] [adversarial loss: -0.057658, acc: 0.000000]
# 15083: [discriminator loss: -0.013974, acc: 0.000000] [adversarial loss: -0.072575, acc: 0.000000]
# 15084: [discriminator loss: -0.010398, acc: 0.003125] [adversarial loss: -0.071868, acc: 0.000000]
# 15085: [discriminator loss: -0.003345, acc: 0.001563] [adversarial loss: -0.070763, acc: 0.000000]
# 15086: [discriminator loss: 0.003028, acc: 0.000000] [adversarial loss: -0.054208, acc: 0.000000]
# 15087: [discriminator loss: -0.011590, acc: 0.000000] [adversarial loss: -0.037989, acc: 0.000000]
# 15088: [discriminator loss: -0.017525, acc: 0.000000] [adversarial loss: -0.013381, acc: 0.000000]
# 15089: [discriminator loss: -0.024218, acc: 0.007812] [adversarial loss: -0.023190, acc: 0.000000]
# 15090: [discriminator loss: -0.015022, acc: 0.017188] [adversarial loss: -0.059244, acc: 0.000000]
# 15091: [discriminator loss: -0.025351, acc: 0.031250] [adversarial loss: -0.066407, acc: 0.015625]
# 15092: [discriminator loss: 0.001302, acc: 0.014063] [adversarial loss: -0.036968, acc: 0.000000]
# 15093: [discriminator loss: -0.013957, acc: 0.020313] [adversarial loss: -0.056407, acc: 0.015625]
# 15094: [discriminator loss: -0.013888, acc: 0.020313] [adversarial loss: -0.049694, acc: 0.000000]
# 15095: [discriminator loss: -0.014289, acc: 0.017188] [adversarial loss: -0.102739, acc: 0.000000]
# 15096: [discriminator loss: -0.029401, acc: 0.017188] [adversarial loss: -0.083531, acc: 0.015625]
# 15097: [discriminator loss: -0.031155, acc: 0.023438] [adversarial loss: -0.137686, acc: 0.046875]
# 15098: [discriminator loss: -0.008715, acc: 0.012500] [adversarial loss: -0.103797, acc: 0.000000]
# 15099: [discriminator loss: -0.021653, acc: 0.015625] [adversarial loss: -0.194557, acc: 0.062500]
# 15100: [discriminator loss: -0.017786, acc: 0.021875] [adversarial loss: -0.144644, acc: 0.062500]
# 15101: [discriminator loss: -0.021662, acc: 0.023438] [adversarial loss: -0.133330, acc: 0.062500]
# 15102: [discriminator loss: -0.030930, acc: 0.029687] [adversarial loss: -0.089729, acc: 0.046875]
# 15103: [discriminator loss: -0.007772, acc: 0.034375] [adversarial loss: -0.165165, acc: 0.078125]
# 15104: [discriminator loss: -0.011875, acc: 0.031250] [adversarial loss: -0.097105, acc: 0.078125]
# 15105: [discriminator loss: 0.017470, acc: 0.021875] [adversarial loss: -0.112778, acc: 0.000000]
# 15106: [discriminator loss: 0.006697, acc: 0.010937] [adversarial loss: -0.113533, acc: 0.000000]
# 15107: [discriminator loss: -0.004593, acc: 0.003125] [adversarial loss: -0.079938, acc: 0.000000]
# 15108: [discriminator loss: 0.000391, acc: 0.000000] [adversarial loss: -0.057144, acc: 0.000000]
# 15109: [discriminator loss: -0.013281, acc: 0.000000] [adversarial loss: -0.044215, acc: 0.000000]
# 15110: [discriminator loss: -0.009209, acc: 0.003125] [adversarial loss: -0.058920, acc: 0.000000]
# 15111: [discriminator loss: -0.020902, acc: 0.000000] [adversarial loss: -0.013224, acc: 0.000000]
# 15112: [discriminator loss: -0.034830, acc: 0.031250] [adversarial loss: -0.023713, acc: 0.062500]
# 15113: [discriminator loss: -0.017053, acc: 0.037500] [adversarial loss: 0.000439, acc: 0.000000]
# 15114: [discriminator loss: -0.003242, acc: 0.023438] [adversarial loss: 0.011418, acc: 0.015625]
# 15115: [discriminator loss: 0.009446, acc: 0.007812] [adversarial loss: -0.038373, acc: 0.000000]
# 15116: [discriminator loss: -0.006079, acc: 0.000000] [adversarial loss: -0.061582, acc: 0.000000]
# 15117: [discriminator loss: -0.015366, acc: 0.000000] [adversarial loss: 0.009349, acc: 0.000000]
# 15118: [discriminator loss: 0.002001, acc: 0.003125] [adversarial loss: -0.006507, acc: 0.000000]
# 15119: [discriminator loss: -0.009388, acc: 0.000000] [adversarial loss: 0.007660, acc: 0.000000]
# 15120: [discriminator loss: -0.016415, acc: 0.006250] [adversarial loss: -0.084120, acc: 0.000000]
# 15121: [discriminator loss: -0.021923, acc: 0.018750] [adversarial loss: -0.042973, acc: 0.031250]
# 15122: [discriminator loss: 0.005373, acc: 0.014063] [adversarial loss: -0.051931, acc: 0.015625]
# 15123: [discriminator loss: 0.001002, acc: 0.004687] [adversarial loss: -0.077435, acc: 0.046875]
# 15124: [discriminator loss: -0.004579, acc: 0.004687] [adversarial loss: -0.052955, acc: 0.000000]
# 15125: [discriminator loss: -0.018018, acc: 0.004687] [adversarial loss: -0.045586, acc: 0.000000]
# 15126: [discriminator loss: -0.011059, acc: 0.003125] [adversarial loss: -0.069118, acc: 0.000000]
# 15127: [discriminator loss: -0.010786, acc: 0.004687] [adversarial loss: -0.077235, acc: 0.000000]
# 15128: [discriminator loss: -0.008495, acc: 0.001563] [adversarial loss: -0.083427, acc: 0.000000]
# 15129: [discriminator loss: -0.013380, acc: 0.001563] [adversarial loss: -0.094352, acc: 0.000000]
# 15130: [discriminator loss: -0.006938, acc: 0.001563] [adversarial loss: -0.099501, acc: 0.000000]
# 15131: [discriminator loss: -0.011008, acc: 0.006250] [adversarial loss: -0.047659, acc: 0.000000]
# 15132: [discriminator loss: -0.000852, acc: 0.004687] [adversarial loss: -0.109823, acc: 0.015625]
# 15133: [discriminator loss: -0.002844, acc: 0.000000] [adversarial loss: -0.083709, acc: 0.000000]
# 15134: [discriminator loss: -0.008281, acc: 0.000000] [adversarial loss: -0.058081, acc: 0.000000]
# 15135: [discriminator loss: -0.005422, acc: 0.000000] [adversarial loss: -0.041729, acc: 0.000000]
# 15136: [discriminator loss: -0.019453, acc: 0.000000] [adversarial loss: -0.059166, acc: 0.000000]
# 15137: [discriminator loss: -0.015274, acc: 0.001563] [adversarial loss: -0.029105, acc: 0.015625]
# 15138: [discriminator loss: -0.012590, acc: 0.001563] [adversarial loss: -0.052657, acc: 0.000000]
# 15139: [discriminator loss: -0.013895, acc: 0.017188] [adversarial loss: -0.042423, acc: 0.046875]
# 15140: [discriminator loss: -0.008031, acc: 0.021875] [adversarial loss: -0.057397, acc: 0.015625]
# 15141: [discriminator loss: 0.005539, acc: 0.004687] [adversarial loss: -0.077112, acc: 0.000000]
# 15142: [discriminator loss: -0.010047, acc: 0.003125] [adversarial loss: -0.047813, acc: 0.000000]
# 15143: [discriminator loss: -0.007496, acc: 0.000000] [adversarial loss: -0.064014, acc: 0.000000]
# 15144: [discriminator loss: -0.013977, acc: 0.000000] [adversarial loss: -0.040528, acc: 0.000000]
# 15145: [discriminator loss: -0.016235, acc: 0.000000] [adversarial loss: -0.081182, acc: 0.000000]
# 15146: [discriminator loss: -0.005885, acc: 0.000000] [adversarial loss: -0.073573, acc: 0.000000]
# 15147: [discriminator loss: -0.017442, acc: 0.003125] [adversarial loss: -0.035731, acc: 0.000000]
# 15148: [discriminator loss: -0.017982, acc: 0.004687] [adversarial loss: -0.041299, acc: 0.000000]
# 15149: [discriminator loss: -0.021043, acc: 0.021875] [adversarial loss: -0.084044, acc: 0.000000]
# 15150: [discriminator loss: -0.016905, acc: 0.007812] [adversarial loss: -0.079289, acc: 0.015625]
# 15151: [discriminator loss: -0.003980, acc: 0.015625] [adversarial loss: -0.084275, acc: 0.015625]
# 15152: [discriminator loss: -0.021581, acc: 0.017188] [adversarial loss: -0.108222, acc: 0.109375]
# 15153: [discriminator loss: -0.002795, acc: 0.015625] [adversarial loss: -0.119390, acc: 0.015625]
# 15154: [discriminator loss: -0.002635, acc: 0.006250] [adversarial loss: -0.093786, acc: 0.000000]
# 15155: [discriminator loss: -0.014902, acc: 0.003125] [adversarial loss: -0.100215, acc: 0.000000]
# 15156: [discriminator loss: -0.006160, acc: 0.004687] [adversarial loss: -0.079156, acc: 0.000000]
# 15157: [discriminator loss: -0.019460, acc: 0.000000] [adversarial loss: -0.060990, acc: 0.000000]
# 15158: [discriminator loss: -0.018149, acc: 0.003125] [adversarial loss: -0.055363, acc: 0.000000]
# 15159: [discriminator loss: -0.015268, acc: 0.004687] [adversarial loss: -0.038546, acc: 0.000000]
# 15160: [discriminator loss: -0.001996, acc: 0.003125] [adversarial loss: -0.081520, acc: 0.015625]
# 15161: [discriminator loss: -0.012191, acc: 0.001563] [adversarial loss: -0.037351, acc: 0.031250]
# 15162: [discriminator loss: -0.005450, acc: 0.009375] [adversarial loss: -0.053874, acc: 0.031250]
# 15163: [discriminator loss: -0.012079, acc: 0.017188] [adversarial loss: -0.057950, acc: 0.015625]
# 15164: [discriminator loss: -0.021790, acc: 0.015625] [adversarial loss: -0.032719, acc: 0.046875]
# 15165: [discriminator loss: -0.015928, acc: 0.009375] [adversarial loss: -0.044484, acc: 0.015625]
# 15166: [discriminator loss: -0.000834, acc: 0.009375] [adversarial loss: -0.055695, acc: 0.000000]
# 15167: [discriminator loss: -0.012373, acc: 0.001563] [adversarial loss: -0.086327, acc: 0.000000]
# 15168: [discriminator loss: -0.009424, acc: 0.003125] [adversarial loss: -0.041252, acc: 0.000000]
# 15169: [discriminator loss: 0.000824, acc: 0.000000] [adversarial loss: -0.037705, acc: 0.000000]
# 15170: [discriminator loss: -0.012402, acc: 0.000000] [adversarial loss: -0.043792, acc: 0.000000]
# 15171: [discriminator loss: -0.019560, acc: 0.000000] [adversarial loss: -0.048899, acc: 0.000000]
# 15172: [discriminator loss: -0.023928, acc: 0.004687] [adversarial loss: -0.013638, acc: 0.015625]
# 15173: [discriminator loss: -0.015837, acc: 0.001563] [adversarial loss: -0.005578, acc: 0.000000]
# 15174: [discriminator loss: -0.021337, acc: 0.003125] [adversarial loss: -0.016156, acc: 0.000000]
# 15175: [discriminator loss: -0.047587, acc: 0.018750] [adversarial loss: -0.030122, acc: 0.015625]
# 15176: [discriminator loss: -0.022985, acc: 0.046875] [adversarial loss: -0.022209, acc: 0.093750]
# 15177: [discriminator loss: -0.009419, acc: 0.032813] [adversarial loss: -0.052797, acc: 0.062500]
# 15178: [discriminator loss: 0.003280, acc: 0.042188] [adversarial loss: -0.056234, acc: 0.031250]
# 15179: [discriminator loss: 0.002490, acc: 0.017188] [adversarial loss: -0.079466, acc: 0.031250]
# 15180: [discriminator loss: 0.006554, acc: 0.014063] [adversarial loss: -0.058053, acc: 0.000000]
# 15181: [discriminator loss: -0.003563, acc: 0.004687] [adversarial loss: -0.081961, acc: 0.000000]
# 15182: [discriminator loss: -0.010103, acc: 0.003125] [adversarial loss: -0.056299, acc: 0.000000]
# 15183: [discriminator loss: -0.013658, acc: 0.015625] [adversarial loss: -0.007474, acc: 0.000000]
# 15184: [discriminator loss: 0.008788, acc: 0.000000] [adversarial loss: -0.063944, acc: 0.000000]
# 15185: [discriminator loss: -0.011840, acc: 0.000000] [adversarial loss: -0.054265, acc: 0.000000]
# 15186: [discriminator loss: -0.012624, acc: 0.001563] [adversarial loss: -0.052423, acc: 0.000000]
# 15187: [discriminator loss: -0.012304, acc: 0.001563] [adversarial loss: -0.047662, acc: 0.000000]
# 15188: [discriminator loss: -0.007200, acc: 0.004687] [adversarial loss: -0.049563, acc: 0.000000]
# 15189: [discriminator loss: -0.024295, acc: 0.007812] [adversarial loss: -0.069161, acc: 0.000000]
# 15190: [discriminator loss: -0.007813, acc: 0.012500] [adversarial loss: -0.046815, acc: 0.000000]
# 15191: [discriminator loss: -0.010472, acc: 0.007812] [adversarial loss: -0.103082, acc: 0.000000]
# 15192: [discriminator loss: -0.007552, acc: 0.006250] [adversarial loss: -0.063229, acc: 0.000000]
# 15193: [discriminator loss: -0.018440, acc: 0.009375] [adversarial loss: -0.064578, acc: 0.000000]
# 15194: [discriminator loss: -0.006584, acc: 0.006250] [adversarial loss: -0.074225, acc: 0.000000]
# 15195: [discriminator loss: -0.010997, acc: 0.003125] [adversarial loss: -0.082460, acc: 0.000000]
# 15196: [discriminator loss: -0.001564, acc: 0.000000] [adversarial loss: -0.067188, acc: 0.000000]
# 15197: [discriminator loss: -0.010721, acc: 0.000000] [adversarial loss: -0.115032, acc: 0.015625]
# 15198: [discriminator loss: -0.009678, acc: 0.000000] [adversarial loss: -0.108584, acc: 0.000000]
# 15199: [discriminator loss: -0.005809, acc: 0.003125] [adversarial loss: -0.089640, acc: 0.000000]
# 15200: [discriminator loss: -0.013302, acc: 0.009375] [adversarial loss: -0.094591, acc: 0.015625]
# 15201: [discriminator loss: -0.015088, acc: 0.003125] [adversarial loss: -0.102281, acc: 0.000000]
# 15202: [discriminator loss: -0.000469, acc: 0.001563] [adversarial loss: -0.084049, acc: 0.000000]
# 15203: [discriminator loss: -0.015724, acc: 0.000000] [adversarial loss: -0.051984, acc: 0.000000]
# 15204: [discriminator loss: -0.001736, acc: 0.000000] [adversarial loss: -0.052422, acc: 0.000000]
# 15205: [discriminator loss: -0.008678, acc: 0.000000] [adversarial loss: -0.051656, acc: 0.015625]
# 15206: [discriminator loss: -0.006200, acc: 0.000000] [adversarial loss: -0.032133, acc: 0.000000]
# 15207: [discriminator loss: -0.018524, acc: 0.000000] [adversarial loss: -0.053185, acc: 0.000000]
# 15208: [discriminator loss: -0.020007, acc: 0.001563] [adversarial loss: -0.075330, acc: 0.000000]
# 15209: [discriminator loss: -0.024298, acc: 0.000000] [adversarial loss: -0.035024, acc: 0.000000]
# 15210: [discriminator loss: -0.031510, acc: 0.001563] [adversarial loss: -0.105803, acc: 0.000000]
# 15211: [discriminator loss: 0.000039, acc: 0.000000] [adversarial loss: -0.041014, acc: 0.000000]
# 15212: [discriminator loss: -0.002605, acc: 0.000000] [adversarial loss: -0.041309, acc: 0.000000]
# 15213: [discriminator loss: -0.008095, acc: 0.000000] [adversarial loss: -0.074950, acc: 0.000000]
# 15214: [discriminator loss: -0.003047, acc: 0.000000] [adversarial loss: -0.029646, acc: 0.000000]
# 15215: [discriminator loss: -0.002977, acc: 0.000000] [adversarial loss: -0.057076, acc: 0.000000]
# 15216: [discriminator loss: -0.004269, acc: 0.000000] [adversarial loss: -0.042488, acc: 0.000000]
# 15217: [discriminator loss: -0.016951, acc: 0.000000] [adversarial loss: -0.031136, acc: 0.000000]
# 15218: [discriminator loss: -0.007725, acc: 0.000000] [adversarial loss: -0.036660, acc: 0.000000]
# 15219: [discriminator loss: -0.019545, acc: 0.000000] [adversarial loss: -0.036839, acc: 0.000000]
# 15220: [discriminator loss: -0.019181, acc: 0.000000] [adversarial loss: -0.070291, acc: 0.000000]
# 15221: [discriminator loss: -0.025152, acc: 0.000000] [adversarial loss: -0.059426, acc: 0.000000]
# 15222: [discriminator loss: -0.015541, acc: 0.004687] [adversarial loss: -0.118787, acc: 0.031250]
# 15223: [discriminator loss: -0.023246, acc: 0.021875] [adversarial loss: -0.101336, acc: 0.015625]
# 15224: [discriminator loss: -0.005166, acc: 0.032813] [adversarial loss: -0.143320, acc: 0.031250]
# 15225: [discriminator loss: -0.015037, acc: 0.026562] [adversarial loss: -0.140796, acc: 0.062500]
# 15226: [discriminator loss: -0.011297, acc: 0.009375] [adversarial loss: -0.156570, acc: 0.031250]
# 15227: [discriminator loss: -0.016194, acc: 0.006250] [adversarial loss: -0.090082, acc: 0.015625]
# 15228: [discriminator loss: -0.014389, acc: 0.020313] [adversarial loss: -0.145132, acc: 0.031250]
# 15229: [discriminator loss: -0.001393, acc: 0.010937] [adversarial loss: -0.094528, acc: 0.015625]
# 15230: [discriminator loss: -0.000347, acc: 0.010937] [adversarial loss: -0.122354, acc: 0.000000]
# 15231: [discriminator loss: -0.007924, acc: 0.001563] [adversarial loss: -0.095287, acc: 0.015625]
# 15232: [discriminator loss: -0.004703, acc: 0.006250] [adversarial loss: -0.066989, acc: 0.000000]
# 15233: [discriminator loss: -0.012034, acc: 0.001563] [adversarial loss: -0.074563, acc: 0.000000]
# 15234: [discriminator loss: -0.011174, acc: 0.003125] [adversarial loss: -0.108478, acc: 0.015625]
# 15235: [discriminator loss: -0.004717, acc: 0.000000] [adversarial loss: -0.051519, acc: 0.000000]
# 15236: [discriminator loss: -0.009228, acc: 0.000000] [adversarial loss: -0.061977, acc: 0.000000]
# 15237: [discriminator loss: -0.001642, acc: 0.000000] [adversarial loss: -0.054250, acc: 0.000000]
# 15238: [discriminator loss: -0.026919, acc: 0.000000] [adversarial loss: 0.039811, acc: 0.015625]
# 15239: [discriminator loss: -0.014900, acc: 0.007812] [adversarial loss: -0.043002, acc: 0.031250]
# 15240: [discriminator loss: -0.003532, acc: 0.021875] [adversarial loss: -0.014347, acc: 0.000000]
# 15241: [discriminator loss: -0.000505, acc: 0.017188] [adversarial loss: -0.045396, acc: 0.000000]
# 15242: [discriminator loss: -0.005061, acc: 0.000000] [adversarial loss: -0.030993, acc: 0.000000]
# 15243: [discriminator loss: -0.014376, acc: 0.000000] [adversarial loss: -0.022562, acc: 0.000000]
# 15244: [discriminator loss: -0.015971, acc: 0.000000] [adversarial loss: -0.028991, acc: 0.000000]
# 15245: [discriminator loss: -0.017729, acc: 0.000000] [adversarial loss: -0.017675, acc: 0.015625]
# 15246: [discriminator loss: -0.006304, acc: 0.009375] [adversarial loss: -0.053245, acc: 0.015625]
# 15247: [discriminator loss: -0.003073, acc: 0.000000] [adversarial loss: -0.022781, acc: 0.000000]
# 15248: [discriminator loss: -0.008460, acc: 0.000000] [adversarial loss: -0.048180, acc: 0.000000]
# 15249: [discriminator loss: -0.005830, acc: 0.000000] [adversarial loss: -0.049809, acc: 0.000000]
# 15250: [discriminator loss: -0.011938, acc: 0.001563] [adversarial loss: -0.033190, acc: 0.031250]
# 15251: [discriminator loss: -0.008505, acc: 0.004687] [adversarial loss: -0.049274, acc: 0.015625]
# 15252: [discriminator loss: -0.013585, acc: 0.015625] [adversarial loss: -0.021990, acc: 0.031250]
# 15253: [discriminator loss: -0.010578, acc: 0.010937] [adversarial loss: -0.044590, acc: 0.031250]
# 15254: [discriminator loss: 0.001860, acc: 0.009375] [adversarial loss: -0.050182, acc: 0.000000]
# 15255: [discriminator loss: -0.008247, acc: 0.000000] [adversarial loss: -0.051544, acc: 0.000000]
# 15256: [discriminator loss: -0.009304, acc: 0.000000] [adversarial loss: -0.016909, acc: 0.000000]
# 15257: [discriminator loss: -0.017534, acc: 0.000000] [adversarial loss: -0.049490, acc: 0.000000]
# 15258: [discriminator loss: -0.012590, acc: 0.000000] [adversarial loss: -0.040645, acc: 0.000000]
# 15259: [discriminator loss: 0.001052, acc: 0.000000] [adversarial loss: -0.032388, acc: 0.000000]
# 15260: [discriminator loss: -0.002140, acc: 0.000000] [adversarial loss: -0.066415, acc: 0.000000]
# 15261: [discriminator loss: -0.008880, acc: 0.000000] [adversarial loss: -0.063075, acc: 0.000000]
# 15262: [discriminator loss: -0.010067, acc: 0.000000] [adversarial loss: -0.045469, acc: 0.000000]
# 15263: [discriminator loss: -0.024479, acc: 0.001563] [adversarial loss: -0.034829, acc: 0.000000]
# 15264: [discriminator loss: -0.018894, acc: 0.004687] [adversarial loss: -0.069232, acc: 0.000000]
# 15265: [discriminator loss: -0.012252, acc: 0.001563] [adversarial loss: -0.066098, acc: 0.000000]
# 15266: [discriminator loss: -0.020943, acc: 0.001563] [adversarial loss: -0.099283, acc: 0.015625]
# 15267: [discriminator loss: -0.004813, acc: 0.015625] [adversarial loss: -0.065694, acc: 0.000000]
# 15268: [discriminator loss: 0.002484, acc: 0.000000] [adversarial loss: -0.105010, acc: 0.000000]
# 15269: [discriminator loss: -0.009867, acc: 0.000000] [adversarial loss: -0.071918, acc: 0.000000]
# 15270: [discriminator loss: -0.024922, acc: 0.001563] [adversarial loss: -0.117925, acc: 0.062500]
# 15271: [discriminator loss: -0.007282, acc: 0.014063] [adversarial loss: -0.111518, acc: 0.046875]
# 15272: [discriminator loss: -0.015873, acc: 0.014063] [adversarial loss: -0.102718, acc: 0.046875]
# 15273: [discriminator loss: -0.011635, acc: 0.015625] [adversarial loss: -0.129183, acc: 0.062500]
# 15274: [discriminator loss: 0.010910, acc: 0.003125] [adversarial loss: -0.111532, acc: 0.015625]
# 15275: [discriminator loss: -0.011323, acc: 0.001563] [adversarial loss: -0.076256, acc: 0.000000]
# 15276: [discriminator loss: -0.012864, acc: 0.007812] [adversarial loss: -0.066414, acc: 0.000000]
# 15277: [discriminator loss: -0.009968, acc: 0.000000] [adversarial loss: -0.054276, acc: 0.000000]
# 15278: [discriminator loss: -0.004445, acc: 0.001563] [adversarial loss: -0.008101, acc: 0.000000]
# 15279: [discriminator loss: -0.008512, acc: 0.003125] [adversarial loss: -0.009585, acc: 0.000000]
# ...
# 19634: [discriminator loss: -0.001331, acc: 0.028125] [adversarial loss: -0.095669, acc: 0.062500]
# 19635: [discriminator loss: -0.017486, acc: 0.032813] [adversarial loss: -0.040249, acc: 0.031250]
# 19636: [discriminator loss: -0.017382, acc: 0.051562] [adversarial loss: -0.060313, acc: 0.046875]
# 19637: [discriminator loss: -0.015808, acc: 0.037500] [adversarial loss: -0.100651, acc: 0.140625]
# 19638: [discriminator loss: -0.008012, acc: 0.046875] [adversarial loss: -0.080215, acc: 0.062500]
# 19639: [discriminator loss: 0.000132, acc: 0.029687] [adversarial loss: -0.085043, acc: 0.031250]
# 19640: [discriminator loss: -0.001735, acc: 0.018750] [adversarial loss: -0.044166, acc: 0.015625]
# 19641: [discriminator loss: -0.016827, acc: 0.004687] [adversarial loss: -0.036763, acc: 0.000000]
# 19642: [discriminator loss: -0.021221, acc: 0.001563] [adversarial loss: -0.085805, acc: 0.000000]
# 19643: [discriminator loss: -0.015267, acc: 0.007812] [adversarial loss: -0.122214, acc: 0.000000]
# 19644: [discriminator loss: -0.008607, acc: 0.017188] [adversarial loss: -0.099859, acc: 0.031250]
# 19645: [discriminator loss: -0.006994, acc: 0.021875] [adversarial loss: -0.135496, acc: 0.046875]
# 19646: [discriminator loss: 0.010769, acc: 0.017188] [adversarial loss: -0.102503, acc: 0.000000]
# 19647: [discriminator loss: 0.003678, acc: 0.015625] [adversarial loss: -0.096882, acc: 0.031250]
# 19648: [discriminator loss: -0.006956, acc: 0.007812] [adversarial loss: -0.070864, acc: 0.000000]
# 19649: [discriminator loss: -0.017643, acc: 0.006250] [adversarial loss: -0.035725, acc: 0.015625]
# 19650: [discriminator loss: -0.015119, acc: 0.007812] [adversarial loss: -0.006496, acc: 0.000000]
# 19651: [discriminator loss: -0.035089, acc: 0.042188] [adversarial loss: -0.026960, acc: 0.078125]
# 19652: [discriminator loss: -0.019457, acc: 0.070312] [adversarial loss: -0.014590, acc: 0.046875]
# 19653: [discriminator loss: -0.005284, acc: 0.039062] [adversarial loss: -0.070457, acc: 0.062500]
# 19654: [discriminator loss: 0.002261, acc: 0.035937] [adversarial loss: -0.111828, acc: 0.031250]
# 19655: [discriminator loss: -0.003860, acc: 0.010937] [adversarial loss: -0.103026, acc: 0.000000]
# 19656: [discriminator loss: -0.010130, acc: 0.003125] [adversarial loss: -0.093948, acc: 0.000000]
# 19657: [discriminator loss: -0.028371, acc: 0.009375] [adversarial loss: -0.073404, acc: 0.000000]
# 19658: [discriminator loss: -0.004925, acc: 0.006250] [adversarial loss: -0.094303, acc: 0.000000]
# 19659: [discriminator loss: -0.025045, acc: 0.003125] [adversarial loss: -0.082864, acc: 0.000000]
# 19660: [discriminator loss: -0.021545, acc: 0.012500] [adversarial loss: -0.111825, acc: 0.000000]
# 19661: [discriminator loss: -0.008033, acc: 0.015625] [adversarial loss: -0.084258, acc: 0.000000]
# 19662: [discriminator loss: 0.007952, acc: 0.018750] [adversarial loss: -0.060287, acc: 0.000000]
# 19663: [discriminator loss: -0.005918, acc: 0.018750] [adversarial loss: -0.113908, acc: 0.000000]
# 19664: [discriminator loss: -0.009853, acc: 0.014063] [adversarial loss: -0.072903, acc: 0.000000]
# 19665: [discriminator loss: -0.019669, acc: 0.017188] [adversarial loss: -0.065950, acc: 0.015625]
# 19666: [discriminator loss: -0.007038, acc: 0.031250] [adversarial loss: -0.027057, acc: 0.000000]
# 19667: [discriminator loss: -0.023921, acc: 0.034375] [adversarial loss: -0.068224, acc: 0.031250]
# 19668: [discriminator loss: 0.014270, acc: 0.042188] [adversarial loss: -0.085421, acc: 0.015625]
# 19669: [discriminator loss: 0.000126, acc: 0.026562] [adversarial loss: -0.017500, acc: 0.000000]
# 19670: [discriminator loss: -0.011366, acc: 0.017188] [adversarial loss: -0.031500, acc: 0.000000]
# 19671: [discriminator loss: -0.021424, acc: 0.034375] [adversarial loss: -0.023105, acc: 0.000000]
# 19672: [discriminator loss: -0.000952, acc: 0.014063] [adversarial loss: -0.058610, acc: 0.000000]
# 19673: [discriminator loss: -0.012137, acc: 0.006250] [adversarial loss: -0.030719, acc: 0.000000]
# 19674: [discriminator loss: -0.017452, acc: 0.009375] [adversarial loss: -0.053931, acc: 0.000000]
# 19675: [discriminator loss: -0.025877, acc: 0.034375] [adversarial loss: -0.025991, acc: 0.000000]
# 19676: [discriminator loss: -0.008515, acc: 0.028125] [adversarial loss: -0.011607, acc: 0.000000]
# 19677: [discriminator loss: -0.027629, acc: 0.046875] [adversarial loss: -0.012817, acc: 0.000000]
# 19678: [discriminator loss: -0.026122, acc: 0.068750] [adversarial loss: -0.055093, acc: 0.000000]
# 19679: [discriminator loss: -0.022922, acc: 0.071875] [adversarial loss: -0.033680, acc: 0.031250]
# 19680: [discriminator loss: -0.028382, acc: 0.098437] [adversarial loss: -0.100134, acc: 0.000000]
# 19681: [discriminator loss: -0.005496, acc: 0.079687] [adversarial loss: -0.086189, acc: 0.031250]
# 19682: [discriminator loss: 0.015445, acc: 0.046875] [adversarial loss: -0.089838, acc: 0.000000]
# 19683: [discriminator loss: -0.007879, acc: 0.034375] [adversarial loss: -0.072790, acc: 0.000000]
# 19684: [discriminator loss: -0.003702, acc: 0.029687] [adversarial loss: -0.096972, acc: 0.000000]
# 19685: [discriminator loss: -0.003145, acc: 0.007812] [adversarial loss: -0.068001, acc: 0.000000]
# 19686: [discriminator loss: -0.010536, acc: 0.012500] [adversarial loss: -0.088028, acc: 0.000000]
# 19687: [discriminator loss: -0.002428, acc: 0.003125] [adversarial loss: -0.088599, acc: 0.000000]
# 19688: [discriminator loss: -0.031012, acc: 0.009375] [adversarial loss: -0.060007, acc: 0.031250]
# 19689: [discriminator loss: -0.008359, acc: 0.028125] [adversarial loss: -0.074143, acc: 0.000000]
# 19690: [discriminator loss: -0.018337, acc: 0.050000] [adversarial loss: -0.082341, acc: 0.031250]
# 19691: [discriminator loss: -0.017748, acc: 0.050000] [adversarial loss: -0.126658, acc: 0.109375]
# 19692: [discriminator loss: 0.021906, acc: 0.020313] [adversarial loss: -0.097380, acc: 0.000000]
# 19693: [discriminator loss: -0.005549, acc: 0.010937] [adversarial loss: -0.122859, acc: 0.015625]
# 19694: [discriminator loss: -0.011854, acc: 0.012500] [adversarial loss: -0.090351, acc: 0.015625]
# 19695: [discriminator loss: 0.002438, acc: 0.006250] [adversarial loss: -0.103595, acc: 0.015625]
# 19696: [discriminator loss: -0.019254, acc: 0.018750] [adversarial loss: -0.109539, acc: 0.046875]
# 19697: [discriminator loss: -0.013436, acc: 0.045312] [adversarial loss: -0.064494, acc: 0.078125]
# 19698: [discriminator loss: -0.002607, acc: 0.023438] [adversarial loss: -0.144553, acc: 0.031250]
# 19699: [discriminator loss: -0.006066, acc: 0.017188] [adversarial loss: -0.178220, acc: 0.046875]
# 19700: [discriminator loss: -0.003581, acc: 0.015625] [adversarial loss: -0.112124, acc: 0.015625]
# 19701: [discriminator loss: -0.012458, acc: 0.012500] [adversarial loss: -0.089152, acc: 0.031250]
# 19702: [discriminator loss: -0.016851, acc: 0.023438] [adversarial loss: -0.128132, acc: 0.078125]
# 19703: [discriminator loss: -0.006734, acc: 0.026562] [adversarial loss: -0.108603, acc: 0.015625]
# 19704: [discriminator loss: 0.004272, acc: 0.023438] [adversarial loss: -0.194857, acc: 0.062500]
# 19705: [discriminator loss: 0.001876, acc: 0.023438] [adversarial loss: -0.125416, acc: 0.031250]
# 19706: [discriminator loss: -0.016954, acc: 0.032813] [adversarial loss: -0.148425, acc: 0.171875]
# 19707: [discriminator loss: -0.022514, acc: 0.059375] [adversarial loss: -0.012417, acc: 0.125000]
# 19708: [discriminator loss: 0.003263, acc: 0.057813] [adversarial loss: -0.091088, acc: 0.156250]
# 19709: [discriminator loss: 0.005595, acc: 0.034375] [adversarial loss: -0.098061, acc: 0.140625]
# 19710: [discriminator loss: -0.000307, acc: 0.021875] [adversarial loss: -0.036325, acc: 0.046875]
# 19711: [discriminator loss: -0.015966, acc: 0.018750] [adversarial loss: -0.028879, acc: 0.015625]
# 19712: [discriminator loss: -0.007158, acc: 0.003125] [adversarial loss: -0.042523, acc: 0.000000]
# 19713: [discriminator loss: -0.031830, acc: 0.001563] [adversarial loss: 0.025859, acc: 0.000000]
# 19714: [discriminator loss: -0.033196, acc: 0.007812] [adversarial loss: 0.005987, acc: 0.000000]
# 19715: [discriminator loss: -0.023439, acc: 0.001563] [adversarial loss: -0.010812, acc: 0.000000]
# 19716: [discriminator loss: -0.024664, acc: 0.004687] [adversarial loss: -0.037020, acc: 0.000000]
# 19717: [discriminator loss: -0.000653, acc: 0.006250] [adversarial loss: -0.041887, acc: 0.000000]
# 19718: [discriminator loss: 0.000182, acc: 0.000000] [adversarial loss: -0.050452, acc: 0.000000]
# 19719: [discriminator loss: -0.018040, acc: 0.003125] [adversarial loss: -0.008241, acc: 0.000000]
# 19720: [discriminator loss: -0.013033, acc: 0.012500] [adversarial loss: -0.053289, acc: 0.031250]
# 19721: [discriminator loss: -0.002365, acc: 0.012500] [adversarial loss: -0.088118, acc: 0.000000]
# 19722: [discriminator loss: -0.010277, acc: 0.006250] [adversarial loss: -0.089253, acc: 0.015625]
# 19723: [discriminator loss: 0.003915, acc: 0.000000] [adversarial loss: -0.045181, acc: 0.000000]
# 19724: [discriminator loss: -0.002352, acc: 0.000000] [adversarial loss: -0.057654, acc: 0.000000]
# 19725: [discriminator loss: -0.003783, acc: 0.001563] [adversarial loss: -0.043027, acc: 0.000000]
# 19726: [discriminator loss: -0.015816, acc: 0.001563] [adversarial loss: -0.054570, acc: 0.015625]
# 19727: [discriminator loss: -0.009483, acc: 0.000000] [adversarial loss: -0.028343, acc: 0.000000]
# 19728: [discriminator loss: -0.012014, acc: 0.000000] [adversarial loss: -0.044199, acc: 0.000000]
# 19729: [discriminator loss: -0.011431, acc: 0.004687] [adversarial loss: -0.055356, acc: 0.000000]
# 19730: [discriminator loss: -0.028995, acc: 0.014063] [adversarial loss: -0.091973, acc: 0.015625]
# 19731: [discriminator loss: -0.006196, acc: 0.017188] [adversarial loss: -0.055120, acc: 0.015625]
# 19732: [discriminator loss: -0.006738, acc: 0.021875] [adversarial loss: -0.062077, acc: 0.000000]
# 19733: [discriminator loss: -0.008529, acc: 0.018750] [adversarial loss: -0.087961, acc: 0.000000]
# 19734: [discriminator loss: 0.008149, acc: 0.006250] [adversarial loss: -0.079588, acc: 0.000000]
# 19735: [discriminator loss: -0.000219, acc: 0.007812] [adversarial loss: -0.067242, acc: 0.000000]
# 19736: [discriminator loss: -0.010591, acc: 0.020313] [adversarial loss: -0.063172, acc: 0.015625]
# 19737: [discriminator loss: -0.007817, acc: 0.040625] [adversarial loss: -0.069603, acc: 0.031250]
# 19738: [discriminator loss: -0.004763, acc: 0.037500] [adversarial loss: -0.105317, acc: 0.046875]
# 19739: [discriminator loss: -0.009818, acc: 0.037500] [adversarial loss: -0.073013, acc: 0.000000]
# 19740: [discriminator loss: -0.006006, acc: 0.035937] [adversarial loss: -0.112649, acc: 0.062500]
# 19741: [discriminator loss: -0.004830, acc: 0.015625] [adversarial loss: -0.105469, acc: 0.015625]
# 19742: [discriminator loss: -0.013238, acc: 0.004687] [adversarial loss: -0.063920, acc: 0.000000]
# 19743: [discriminator loss: -0.023757, acc: 0.006250] [adversarial loss: -0.046995, acc: 0.000000]
# 19744: [discriminator loss: -0.006832, acc: 0.004687] [adversarial loss: -0.088290, acc: 0.000000]
# 19745: [discriminator loss: 0.000476, acc: 0.003125] [adversarial loss: -0.083790, acc: 0.000000]
# 19746: [discriminator loss: -0.025745, acc: 0.004687] [adversarial loss: -0.107992, acc: 0.000000]
# 19747: [discriminator loss: -0.024648, acc: 0.025000] [adversarial loss: -0.124479, acc: 0.015625]
# 19748: [discriminator loss: -0.009214, acc: 0.025000] [adversarial loss: -0.111459, acc: 0.031250]
# 19749: [discriminator loss: -0.026917, acc: 0.031250] [adversarial loss: -0.092642, acc: 0.062500]
# 19750: [discriminator loss: -0.007712, acc: 0.042188] [adversarial loss: -0.136968, acc: 0.078125]
# 19751: [discriminator loss: 0.006864, acc: 0.026562] [adversarial loss: -0.147261, acc: 0.031250]
# 19752: [discriminator loss: -0.012250, acc: 0.021875] [adversarial loss: -0.114542, acc: 0.031250]
# 19753: [discriminator loss: 0.005385, acc: 0.012500] [adversarial loss: -0.075714, acc: 0.015625]
# 19754: [discriminator loss: -0.001492, acc: 0.001563] [adversarial loss: -0.141725, acc: 0.062500]
# 19755: [discriminator loss: -0.011596, acc: 0.007812] [adversarial loss: -0.072297, acc: 0.031250]
# 19756: [discriminator loss: -0.023642, acc: 0.021875] [adversarial loss: -0.168804, acc: 0.156250]
# 19757: [discriminator loss: 0.010572, acc: 0.021875] [adversarial loss: -0.110707, acc: 0.046875]
# 19758: [discriminator loss: 0.004478, acc: 0.006250] [adversarial loss: -0.106793, acc: 0.062500]
# 19759: [discriminator loss: -0.006030, acc: 0.003125] [adversarial loss: -0.089338, acc: 0.000000]
# 19760: [discriminator loss: -0.016864, acc: 0.003125] [adversarial loss: -0.099660, acc: 0.046875]
# 19761: [discriminator loss: -0.020246, acc: 0.020313] [adversarial loss: -0.114414, acc: 0.062500]
# 19762: [discriminator loss: -0.004750, acc: 0.012500] [adversarial loss: -0.092687, acc: 0.015625]
# 19763: [discriminator loss: -0.019097, acc: 0.001563] [adversarial loss: -0.105931, acc: 0.062500]
# 19764: [discriminator loss: -0.013818, acc: 0.006250] [adversarial loss: -0.093007, acc: 0.000000]
# 19765: [discriminator loss: -0.009069, acc: 0.003125] [adversarial loss: -0.098232, acc: 0.015625]
# 19766: [discriminator loss: -0.006627, acc: 0.004687] [adversarial loss: -0.020010, acc: 0.000000]
# 19767: [discriminator loss: -0.026796, acc: 0.021875] [adversarial loss: 0.010097, acc: 0.078125]
# 19768: [discriminator loss: 0.009003, acc: 0.015625] [adversarial loss: -0.005664, acc: 0.000000]
# 19769: [discriminator loss: -0.027297, acc: 0.020313] [adversarial loss: 0.046436, acc: 0.046875]
# 19770: [discriminator loss: -0.004066, acc: 0.021875] [adversarial loss: 0.046381, acc: 0.078125]
# 19771: [discriminator loss: -0.005221, acc: 0.026562] [adversarial loss: -0.022237, acc: 0.078125]
# 19772: [discriminator loss: -0.009283, acc: 0.025000] [adversarial loss: 0.029030, acc: 0.046875]
# 19773: [discriminator loss: -0.012704, acc: 0.021875] [adversarial loss: 0.026864, acc: 0.000000]
# 19774: [discriminator loss: -0.029595, acc: 0.004687] [adversarial loss: 0.034506, acc: 0.000000]
# 19775: [discriminator loss: -0.046867, acc: 0.003125] [adversarial loss: -0.006251, acc: 0.015625]
# 19776: [discriminator loss: -0.035095, acc: 0.007812] [adversarial loss: 0.003394, acc: 0.015625]
# 19777: [discriminator loss: -0.014552, acc: 0.010937] [adversarial loss: -0.029503, acc: 0.000000]
# 19778: [discriminator loss: -0.004677, acc: 0.003125] [adversarial loss: -0.022985, acc: 0.015625]
# 19779: [discriminator loss: -0.014821, acc: 0.004687] [adversarial loss: -0.101787, acc: 0.000000]
# 19780: [discriminator loss: -0.002781, acc: 0.003125] [adversarial loss: -0.014578, acc: 0.000000]
# 19781: [discriminator loss: -0.007119, acc: 0.012500] [adversarial loss: -0.021715, acc: 0.031250]
# 19782: [discriminator loss: -0.007587, acc: 0.021875] [adversarial loss: -0.020232, acc: 0.046875]
# 19783: [discriminator loss: 0.004567, acc: 0.028125] [adversarial loss: -0.066710, acc: 0.000000]
# 19784: [discriminator loss: -0.002604, acc: 0.029687] [adversarial loss: -0.056471, acc: 0.031250]
# 19785: [discriminator loss: -0.004721, acc: 0.014063] [adversarial loss: -0.058905, acc: 0.000000]
# 19786: [discriminator loss: -0.007181, acc: 0.014063] [adversarial loss: -0.080510, acc: 0.000000]
# 19787: [discriminator loss: -0.014234, acc: 0.020313] [adversarial loss: -0.070572, acc: 0.000000]
# 19788: [discriminator loss: -0.025142, acc: 0.014063] [adversarial loss: -0.103308, acc: 0.046875]
# 19789: [discriminator loss: -0.017288, acc: 0.017188] [adversarial loss: -0.114885, acc: 0.015625]
# 19790: [discriminator loss: -0.017272, acc: 0.009375] [adversarial loss: -0.122254, acc: 0.031250]
# 19791: [discriminator loss: -0.015204, acc: 0.017188] [adversarial loss: -0.102296, acc: 0.031250]
# 19792: [discriminator loss: -0.003473, acc: 0.020313] [adversarial loss: -0.100695, acc: 0.015625]
# 19793: [discriminator loss: -0.014428, acc: 0.017188] [adversarial loss: -0.170760, acc: 0.046875]
# 19794: [discriminator loss: -0.011267, acc: 0.014063] [adversarial loss: -0.151523, acc: 0.046875]
